# %% [markdown]
# # Reading events from PPs and adding Tracking
#
# Currently the code will read the PPs from the pp_info.csv file, then it will find relevant events from the event file that match. After that it will attempt to get tracking data that is relevant.
#
# First it will figure out the time of the event relevant to the frame time of the tracking info (use the videoShotsInfo files). Then it will assign each file with the tracking data between it and then next event. In order to avoid events that are close together not getting any tracking at all I assign 15 frames back and 15 forward to each event just in case (1 second extra tracking), this also accounts for the limited granularity in the event timing (which is 1 sec vs 30 fps for tracking)
#
# Tracking data is corrected as per the tweet we found, but not doing anything about gaps or about "player 100s"
#
# I am not saving it at the moment because it is nested and doesn't take long to run.

# %%
from read_and_join_events_tracking import *
import os

# print(os.path.join('../','pxp_womens_oly_2022_v2.csv'))

relevant_events = get_pp_tracking(tracking_dir='./', pbp_dir = '../')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11436/2121641300.py in <module>
#       4 # print(os.path.join('../','pxp_womens_oly_2022_v2.csv'))
#       5
# ----> 6 relevant_events = get_pp_tracking(tracking_dir='./', pbp_dir = '../')
#
# ~\Desktop\Big-Data-Cup-2022-Private\code\data_manipulation\read_and_join_events_tracking.py in get_pp_tracking(power_play_info_file, play_by_play_data_file, tracking_dir, pbp_dir)
#      80     pbp_dir = './'):
#      81
# ---> 82     play_by_play_data = pd.read_csv(os.path.join(pbp_dir,play_by_play_data_file))
#      83     power_play_info = pd.read_csv(os.path.join(tracking_dir,power_play_info_file))
#      84
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../pxp_womens_oly_2022_v2.csv'

# %% [markdown]
# #Example of the format of the output:
#
# A dataframe containing each PP, with a column named "relevant_events" which contains a DF with event data

# %%
relevant_events.head()
# Out:
#                   game_name  penalty_number  start_video_clock_seconds  \
# 0  2022-02-08 Canada at USA               1                       1278
# 1  2022-02-08 Canada at USA               2                       1624
# 2  2022-02-08 Canada at USA               3                        409
# 3  2022-02-08 Canada at USA               4                        898
# 4  2022-02-08 Canada at USA               5                       1690
#
#    end_video_clock_seconds  start_period  end_period  \
# 0                     1314             1           1
# 1                     1744             1           1
# 2                      562             2           2
# 3                      898             2           2
# 4                     1927             2           2
#
#    start_game_clock_seconds  end_game_clock_seconds  \
# 0                       386                     350
# 1                       216                      96
# 2                       991                     871
# 3                       613                     613
# 4                       272                     152
#
#                                      relevant_events
# 0     game_date  season_year                     ...
# 1     game_date  season_year                     ...
# 2     game_date  season_year                     ...
# 3                                               None
# 4     game_date  season_year                     ...

# %% [markdown]
# Example of one DF of event data, which contains a column of tracking data called "tracks", which itself is a DF

# %%
relevant_events.loc[0,'relevant_events'].head()
# Out:
#   game_date  season_year                        team_name  \
# 0  8/2/2022         2021  Olympic (Women) - United States
# 1  8/2/2022         2021  Olympic (Women) - United States
# 2  8/2/2022         2021  Olympic (Women) - United States
# 3  8/2/2022         2021  Olympic (Women) - United States
# 4  8/2/2022         2021         Olympic (Women) - Canada
#
#                      opp_team_name venue  period  clock_seconds  \
# 0         Olympic (Women) - Canada  home       1            386
# 1         Olympic (Women) - Canada  home       1            386
# 2         Olympic (Women) - Canada  home       1            383
# 3         Olympic (Women) - Canada  home       1            382
# 4  Olympic (Women) - United States  away       1            380
#
#   situation_type  goals_for  goals_against  ...      event_type  \
# 0         5 on 5          0              0  ...  Cross-checking
# 1         4 on 5          0              0  ...        Backhand
# 2         4 on 5          0              0  ...             NaN
# 3         4 on 5          0              0  ...             NaN
# 4         5 on 4          0              0  ...             NaN
#
#          player_name_2 x_coord_2  y_coord_2  event_detail_1 event_detail_2  \
# 0        Sarah Fillier       NaN        NaN             NaN            NaN
# 1  Marie-Philip Poulin       NaN        NaN             NaN            NaN
# 2                  NaN       NaN        NaN             NaN            NaN
# 3                  NaN       NaN        NaN             NaN            NaN
# 4                  NaN       NaN        NaN             NaN            NaN
#
#   event_detail_3  Player_1_num  Player_2_num tracks
# 0            NaN             4          10.0   None
# 1            NaN            25          29.0   None
# 2            NaN             2           NaN   None
# 3            NaN             2           NaN   None
# 4            NaN            10           NaN   None
#
# [5 rows x 25 columns]

# %% [markdown]
# Finally, an example of one DF of tracking data

# %%
relevant_events.loc[0,'relevant_events'].tracks.iloc[6]
# Out:
#      frame_id  period  track_id team_id team_name  jersey_number        x_ft  \
# 98        315       1         1   Light    Canada              6  166.412354
# 99        315       1         2    Dark       USA              2  183.106257
# 100       315       1         3    Dark       USA             37  187.198140
# 101       315       1         4   Light    Canada             11  195.635778
# 102       315       1         5    Dark       USA             28  166.892412
# ..        ...     ...       ...     ...       ...            ...         ...
# 805       404       1        13   Light    Canada            100  155.659857
# 806       404       1        16   Light    Canada              6  154.330091
# 807       404       1        18    Dark       USA              3  183.735250
# 808       404       1         7    Dark       USA              5  173.488274
# 809       404       1        22    Dark       USA             10  184.469731
#
#           y_ft      vel_x     vel_y
# 98   54.525812   5.482729  8.911096
# 99   48.074749  -6.806727  4.755684
# 100  51.961487   1.554065  0.914565
# 101  73.999070   2.143761  1.141240
# 102  46.917458   2.140943  8.115468
# ..         ...        ...       ...
# 805  82.385167  14.886233  2.931767
# 806  64.552903  -8.442085  2.744008
# 807  55.444952  -0.549836 -2.666694
# 808  67.395426  -1.012685  3.871421
# 809  44.093598   2.771149  5.035321
#
# [712 rows x 10 columns]

# %%
# tracks = relevant_events.loc[0,'relevant_events'].tracks.iloc[6].copy()
# tracks['vel_x'] = 0
# tracks['vel_y'] = 0
# tr_ids = tracks.track_id.unique()
# for tr_id in tr_ids:
#     idxs = tracks.track_id==tr_id
#     track = tracks.loc[idxs]
#     x_spd,y_spd = get_speed(track)
#     tracks.loc[idxs,'vel_x'] = x_spd
#     tracks.loc[idxs,'vel_y'] = y_spd
#     break
# print(tracks.head())

# %%
relevant_events.to_json(r'BDC_2022_all_data.json')
